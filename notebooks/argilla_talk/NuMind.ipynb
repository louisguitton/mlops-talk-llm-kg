# %%
import argilla as rg

# %%
rg.init(
    api_url="http://localhost:6900",
    api_key="admin.apikey",
)
# Out:
# /Users/louis.guitton/workspace/mlops-talk-llm-kg/venv/lib/python3.11/site-packages/argilla/client/client.py:178: UserWarning: No workspace configuration was detected. To work with Argilla datasets, specify a valid workspace name on `rg.init` or set it up through the `rg.set_workspace` function.
#   warnings.warn(

# %%
ds = rg.FeedbackDataset.from_huggingface("numind/NuNER")
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /Users/louis.guitton/workspace/mlops-talk-llm-kg/venv/lib/python3.11/site-packages/huggingface_h │
# │ ub/utils/_errors.py:286 in hf_raise_for_status                                                   │
# │                                                                                                  │
# │   283 │   </Tip>                                                                                 │
# │   284 │   """                                                                                    │
# │   285 │   try:                                                                                   │
# │ ❱ 286 │   │   response.raise_for_status()                                                        │
# │   287 │   except HTTPError as e:                                                                 │
# ...
